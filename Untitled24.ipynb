# %% [markdown]
# <a href="https://colab.research.google.com/github/uujimin/-Jeju_Island_Tourist_Prediction/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 라이브러리 불러오기

# %%
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_csv('빅콘.csv')
df
# Out:
#     base_month  Vacation  holiday  season  weekend  Average temperature (°C)  \
# 0     201501.0       1.0      1.0  winter      9.0                       7.4
# 1     201502.0       0.0      3.0  winter      4.0                       7.3
# 2     201503.0       0.0      1.0  spring      8.0                      10.4
# 3     201504.0       0.0      0.0  spring      6.0                      15.1
# 4     201505.0       0.0      2.0  spring     10.0                      18.8
# ..         ...       ...      ...     ...      ...                       ...
# 87    202204.0       0.0      1.0  spring      9.0                      15.5
# 88    202205.0       0.0      2.0  spring      9.0                      19.4
# 89    202206.0       1.0      0.0  summer      8.0                      23.9
# 90    202207.0       1.0      1.0  summer     10.0                      28.4
# 91         NaN       NaN      NaN     NaN      NaN                       NaN
#
#     Average maximum temperature (°C)  Average minimum temperature (°C)  \
# 0                               10.2                               4.9
# 1                               10.1                               4.7
# 2                               13.6                               7.3
# 3                               19.2                              12.0
# 4                               22.7                              15.9
# ..                               ...                               ...
# 87                              19.6                              11.9
# 88                              23.1                              15.8
# 89                              27.5                              21.1
# 90                              31.8                              25.7
# 91                               NaN                               NaN
#
#     Maximum temperature (°C)  Minimum temperature (°C)  ...  0.1m평균지중온도(°C)  \
# 0                       17.5                       1.2  ...             7.2
# 1                       17.3                      -0.7  ...             7.3
# 2                       22.2                       0.2  ...            11.1
# 3                       27.7                       7.0  ...            16.2
# 4                       29.4                      11.0  ...            21.6
# ..                       ...                       ...  ...             ...
# 87                      26.7                       5.6  ...            17.3
# 88                      29.0                       9.5  ...            21.5
# 89                      34.4                      17.3  ...            26.0
# 90                      36.0                      23.2  ...            30.6
# 91                       NaN                       NaN  ...            30.5
#
#     0.2m평균지중온도(°C)  0.3m평균지중온도(°C)  0.5m평균지중온도(°C)  1.0m평균지중온도(°C)  \
# 0              7.7             7.9             8.5             9.6
# 1              7.5             7.6             7.8             8.0
# 2             10.9            10.7            10.5             9.6
# 3             15.9            15.6            15.4            13.7
# 4             21.2            20.8            20.4            18.1
# ..             ...             ...             ...             ...
# 87            17.2            16.7            16.4            14.8
# 88            21.6            21.2            20.8            18.8
# 89            25.9            25.4            24.9            22.5
# 90            30.6            30.2            29.5            27.2
# 91            30.7            30.6            30.2            28.5
#
#     1.5m평균지중온도(°C)  3.0m평균지중온도(°C)  5.0m평균지중온도(°C)  leis_sports_cnt  \
# 0              9.6            15.6            18.4         127063.0
# 1              7.7            12.2            16.9         134718.0
# 2              8.9            11.1            15.8         143528.0
# 3             12.6            12.1            14.9         146259.0
# 4             16.3            14.7            14.8         179944.0
# ..             ...             ...             ...              ...
# 87            13.9            13.9            16.5         102377.0
# 88            17.2            15.6            16.1          94892.0
# 89            20.4            17.9            16.5         106281.0
# 90            24.8            22.0            17.7          93984.0
# 91            26.8            24.5            19.7              NaN
#
#     ref_view_cnt
# 0       521304.0
# 1       459032.0
# 2       490004.0
# 3       623087.0
# 4       628479.0
# ..           ...
# 87      843283.0
# 88      918511.0
# 89      970029.0
# 90      940925.0
# 91           NaN
#
# [92 rows x 73 columns]

# %% [markdown]
# ## 빅 콘테스트는 7월 데이터 까지 있으므로 마지막 2022년 8월 데이터는 삭제해준다.

# %%
df = df.drop(91, axis=0)
df
# Out:
#     base_month  Vacation  holiday  season  weekend  Average temperature (°C)  \
# 0     201501.0       1.0      1.0  winter      9.0                       7.4
# 1     201502.0       0.0      3.0  winter      4.0                       7.3
# 2     201503.0       0.0      1.0  spring      8.0                      10.4
# 3     201504.0       0.0      0.0  spring      6.0                      15.1
# 4     201505.0       0.0      2.0  spring     10.0                      18.8
# ..         ...       ...      ...     ...      ...                       ...
# 86    202203.0       0.0      2.0  spring      8.0                      11.4
# 87    202204.0       0.0      1.0  spring      9.0                      15.5
# 88    202205.0       0.0      2.0  spring      9.0                      19.4
# 89    202206.0       1.0      0.0  summer      8.0                      23.9
# 90    202207.0       1.0      1.0  summer     10.0                      28.4
#
#     Average maximum temperature (°C)  Average minimum temperature (°C)  \
# 0                               10.2                               4.9
# 1                               10.1                               4.7
# 2                               13.6                               7.3
# 3                               19.2                              12.0
# 4                               22.7                              15.9
# ..                               ...                               ...
# 86                              15.5                               7.8
# 87                              19.6                              11.9
# 88                              23.1                              15.8
# 89                              27.5                              21.1
# 90                              31.8                              25.7
#
#     Maximum temperature (°C)  Minimum temperature (°C)  ...  0.1m평균지중온도(°C)  \
# 0                       17.5                       1.2  ...             7.2
# 1                       17.3                      -0.7  ...             7.3
# 2                       22.2                       0.2  ...            11.1
# 3                       27.7                       7.0  ...            16.2
# 4                       29.4                      11.0  ...            21.6
# ..                       ...                       ...  ...             ...
# 86                      22.3                       4.5  ...            11.8
# 87                      26.7                       5.6  ...            17.3
# 88                      29.0                       9.5  ...            21.5
# 89                      34.4                      17.3  ...            26.0
# 90                      36.0                      23.2  ...            30.6
#
#     0.2m평균지중온도(°C)  0.3m평균지중온도(°C)  0.5m평균지중온도(°C)  1.0m평균지중온도(°C)  \
# 0              7.7             7.9             8.5             9.6
# 1              7.5             7.6             7.8             8.0
# 2             10.9            10.7            10.5             9.6
# 3             15.9            15.6            15.4            13.7
# 4             21.2            20.8            20.4            18.1
# ..             ...             ...             ...             ...
# 86            11.8            11.4            11.3            10.7
# 87            17.2            16.7            16.4            14.8
# 88            21.6            21.2            20.8            18.8
# 89            25.9            25.4            24.9            22.5
# 90            30.6            30.2            29.5            27.2
#
#     1.5m평균지중온도(°C)  3.0m평균지중온도(°C)  5.0m평균지중온도(°C)  leis_sports_cnt  \
# 0              9.6            15.6            18.4         127063.0
# 1              7.7            12.2            16.9         134718.0
# 2              8.9            11.1            15.8         143528.0
# 3             12.6            12.1            14.9         146259.0
# 4             16.3            14.7            14.8         179944.0
# ..             ...             ...             ...              ...
# 86            10.7            13.5            17.2          74732.0
# 87            13.9            13.9            16.5         102377.0
# 88            17.2            15.6            16.1          94892.0
# 89            20.4            17.9            16.5         106281.0
# 90            24.8            22.0            17.7          93984.0
#
#     ref_view_cnt
# 0       521304.0
# 1       459032.0
# 2       490004.0
# 3       623087.0
# 4       628479.0
# ..           ...
# 86      617995.0
# 87      843283.0
# 88      918511.0
# 89      970029.0
# 90      940925.0
#
# [91 rows x 73 columns]

# %% [markdown]
# # 전처리 과정

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 90
# Data columns (total 73 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   base_month                                                  91 non-null     float64
#  1   Vacation                                                    91 non-null     float64
#  2   holiday                                                     91 non-null     float64
#  3   season                                                      91 non-null     object
#  4   weekend                                                     91 non-null     float64
#  5   Average temperature (°C)                                    91 non-null     float64
#  6   Average maximum temperature (°C)                            91 non-null     float64
#  7   Average minimum temperature (°C)                            91 non-null     float64
#  8   Maximum temperature (°C)                                    91 non-null     float64
#  9   Minimum temperature (°C)                                    91 non-null     float64
#  10  The day the highest temperature appeared (yyyymmdd)         91 non-null     float64
#  11  The day the lowest temperature appeared (yyyymmdd)          91 non-null     float64
#  12  평균현지기압(hPa)                                                 91 non-null     float64
#  13  평균해면기압(hPa)                                                 91 non-null     float64
#  14  최고해면기압(hPa)                                                 91 non-null     float64
#  15  최저해면기압(hPa)                                                 91 non-null     float64
#  16  최고해면기압 나타난날(yyyymmdd)                                       91 non-null     float64
#  17  최저해면기압 나타난날(yyyymmdd)                                       91 non-null     float64
#  18  평균수증기압(hPa)                                                 91 non-null     float64
#  19  최고수증기압(hPa)                                                 91 non-null     float64
#  20  최저수증기압(hPa)                                                 91 non-null     float64
#  21  최고수증기압 나타난날(yyyymmdd)                                       91 non-null     float64
#  22  최저수증기압 나타난날(yyyymmdd)                                       91 non-null     float64
#  23  평균이슬점온도(°C)                                                 91 non-null     float64
#  24  평균상대습도(%)                                                   91 non-null     float64
#  25  최소상대습도(%)                                                   91 non-null     float64
#  26  최소상대습도 나타난날(yyyymmdd)                                       91 non-null     float64
#  27  Monthly precipitation (00~24hten thousand)(mm)              91 non-null     float64
#  28  일최다강수량(mm)                                                  91 non-null     float64
#  29  1시간최다강수량(mm)                                                53 non-null     float64
#  30  10분최다강수량(mm)                                                53 non-null     float64
#  31  일최다강수량 나타난날(yyyymmdd)                                       91 non-null     float64
#  32  1시간최다강수량 나타난날(yyyymmdd)                                     53 non-null     float64
#  33  10분최다강수량 나타난날(yyyymmdd)                                     53 non-null     float64
#  34  소형총증발량(mm)                                                  91 non-null     float64
#  35  소형일최대증발량(mm)                                                91 non-null     float64
#  36  대형총증발량(mm)                                                  86 non-null     float64
#  37  대형일최대증발량(mm)                                                86 non-null     float64
#  38  소형일최대증발량 나타난날(yyyymmdd)                                     91 non-null     float64
#  39  대형일최대증발량 나타난날(yyyymmdd)                                     86 non-null     float64
#  40  Average wind speed (m/s)                                    91 non-null     float64
#  41  Maximum wind speed (m/s)                                    91 non-null     float64
#  42  최대순간풍속(m/s)                                                 91 non-null     float64
#  43  최대풍속 풍향(16방위)                                               91 non-null     float64
#  44  최대순간풍속 풍향(16방위)                                             91 non-null     float64
#  45  The day the maximum wind speed appeared (yyyymmdd)          91 non-null     float64
#  46  최대순간풍속 나타난날(yyyymmdd)                                       91 non-null     float64
#  47  최다풍향(16방위)                                                  91 non-null     float64
#  48  Average Cloudiness (1/10)                                   91 non-null     float64
#  49  평균중하층운량(1/10)                                               89 non-null     float64
#  50  합계 일조시간(hr)                                                 91 non-null     float64
#  51  일조율(%)                                                      91 non-null     float64
#  52  합계 일사량(MJ/m2)                                               91 non-null     float64
#  53  최심적설(cm)                                                    14 non-null     float64
#  54  최심신적설(cm)                                                   14 non-null     float64
#  55  3시간신적설합(cm)                                                 15 non-null     float64
#  56  최심적설 나타난날(yyyymmdd)                                         14 non-null     float64
#  57  최심신적설 나타난날(yyyymmdd)                                        14 non-null     float64
#  58  평균 최저초상온도(°C)                                               91 non-null     float64
#  59  최저초상온도(°C)                                                  91 non-null     float64
#  60  최저초상온도 나타난날(yyyymmdd)                                       91 non-null     int64
#  61  평균지면온도(°C)                                                  91 non-null     float64
#  62  0.05m평균지중온도(°C)                                             91 non-null     float64
#  63  0.1m평균지중온도(°C)                                              91 non-null     float64
#  64  0.2m평균지중온도(°C)                                              91 non-null     float64
#  65  0.3m평균지중온도(°C)                                              91 non-null     float64
#  66  0.5m평균지중온도(°C)                                              91 non-null     float64
#  67  1.0m평균지중온도(°C)                                              91 non-null     float64
#  68  1.5m평균지중온도(°C)                                              91 non-null     float64
#  69  3.0m평균지중온도(°C)                                              91 non-null     float64
#  70  5.0m평균지중온도(°C)                                              91 non-null     float64
#  71  leis_sports_cnt                                             91 non-null     float64
#  72  ref_view_cnt                                                91 non-null     float64
# dtypes: float64(71), int64(1), object(1)
# memory usage: 52.6+ KB

# %% [markdown]
# # 데이터 컬럼 설명
#
#
# ---
#
# |컬럼|의미|
# |---|---|
# |Vacation|방학|
# |holiday|공휴일|
# |season|계절|
# |weekend|주말|
# |Average temperature (°C)|평균기온(°C)|
# |Average maximum temperature (°C)|평균최고기온(°C)|
# |Average minimum temperature (°C)|평균최저기온(°C)|
# |Maximum temperature (°C)|최고기온(°C)|
# |Minimum temperature (°C)|최저기온(°C)|
# |The day the highest temperature appeared (yyyymmdd)|최고기온 나타난날(yyyymmdd)|
# |The day the lowest temperature appeared (yyyymmdd)|최저기온 나타난날(yyyymmdd)|
# |Monthly precipitation (00~24hten thousand)(mm)|월합강수량(00~24h만)(mm))|
# |Average wind speed (m/s)|평균풍속(m/s)|
# |Maximum wind speed (m/s)|최대풍속(m/s)|
# |The day the maximum wind speed appeared (yyyymmdd)|최대풍속 나타난날(yyyymmdd)|
# |Average Cloudiness (1/10)|평균운량(1/10)|
# |leis_sports_cnt|레저스포츠|
# |ref_view_cnt|뷰|

# %% [markdown]
# ## 데이터를 살펴보니 결측치가 존재하는 컬럼이 보인다.
#
# 따라서 결측치가 존재하는 컬럼을 삭제해준다

# %%
# 결측치가 존재하는 컬럼은 13개이다. 따라서 13개의 컬럼을 삭제해 준다.
df = df.dropna(axis=1)

# %% [markdown]
# ## EDA 과정
#
# 본대회의 예측을 수행하기 위하여 중요하다고 생각하는 컬럼은 [Vacation, holiday, season, weekend, Average temperature (°C), Average maximum temperature (°C), Average minimum temperature (°C), Maximum temperature (°C), Minimum temperature (°C), Average wind speed (m/s)]과 같다
#
# 따라서 다음의 EDA 분석을 실시하고자 한다.

# %% [markdown]
# ### Vacation분석

# %%
# 상관관계 분석을 해 보니 vacation(0.01)과 ref_view_cnt(0.3)가 상관관계가 있고,
# leis_sports_cnt(-0.1)는 상관관계가 없다.
df_vacation = df[["Vacation","leis_sports_cnt","ref_view_cnt"]]
df_vacation.corr()
# Out:
#                  Vacation  leis_sports_cnt  ref_view_cnt
# Vacation         1.000000        -0.140896      0.391629
# leis_sports_cnt -0.140896         1.000000      0.087771
# ref_view_cnt     0.391629         0.087771      1.000000

# %% [markdown]
# ### holiday분석

# %%
# 상관관계 분석을 해 보니 holiday와 leis_sports_cnt(0.003), 
# ref_view_cnt(-0.08) 둘 다 관계가 없다.
df_holiday = df[["holiday","leis_sports_cnt","ref_view_cnt"]]
df_holiday.corr()
# Out:
#                   holiday  leis_sports_cnt  ref_view_cnt
# holiday          1.000000         0.003873     -0.083187
# leis_sports_cnt  0.003873         1.000000      0.087771
# ref_view_cnt    -0.083187         0.087771      1.000000

# %% [markdown]
# ### weekend분석

# %%
# 상관관계 분석을 해 보니 weekend와 leis_sports_cnt(0.01), 
# ref_view_cnt(0.2) 둘 다 관계가 없다.
df_weekend = df[["weekend","leis_sports_cnt","ref_view_cnt"]]
df_weekend.corr()
# Out:
#                   weekend  leis_sports_cnt  ref_view_cnt
# weekend          1.000000         0.015566      0.202462
# leis_sports_cnt  0.015566         1.000000      0.087771
# ref_view_cnt     0.202462         0.087771      1.000000

# %% [markdown]
# ### Average temperature (°C)분석

# %%
# 상관관계 분석을 해 보니 Average temperature (°C)와 leis_sports_cnt(0.5), 
# ref_view_cnt(0.5) 둘 다 관계가 깊다.
df_Average_temperature = df[["Average temperature (°C)","leis_sports_cnt","ref_view_cnt"]]
df_Average_temperature.corr()
# Out:
#                           Average temperature (°C)  leis_sports_cnt  \
# Average temperature (°C)                  1.000000        -0.178488
# leis_sports_cnt                          -0.178488         1.000000
# ref_view_cnt                              0.552147         0.087771
#
#                           ref_view_cnt
# Average temperature (°C)      0.552147
# leis_sports_cnt               0.087771
# ref_view_cnt                  1.000000

# %% [markdown]
# ### Average maximum temperature (°C)분석

# %%
# 상관관계 분석을 해 보니 Average maximum temperature (°C)와 leis_sports_cnt(-0.1)는 관계가 없고, 
# ref_view_cnt(0.5)하고는 관계가 깊다.
df_Average_maximum_temperature = df[["Average maximum temperature (°C)","leis_sports_cnt","ref_view_cnt"]]
df_Average_maximum_temperature.corr()
# Out:
#                                   Average maximum temperature (°C)  \
# Average maximum temperature (°C)                          1.000000
# leis_sports_cnt                                          -0.174064
# ref_view_cnt                                              0.551348
#
#                                   leis_sports_cnt  ref_view_cnt
# Average maximum temperature (°C)        -0.174064      0.551348
# leis_sports_cnt                          1.000000      0.087771
# ref_view_cnt                             0.087771      1.000000

# %% [markdown]
# ### Average minimum temperature (°C)분석

# %%
# 상관관계 분석을 해 보니 Average minimum temperature (°C)와 leis_sports_cnt(-0.1)는 상관관계가 없고,
# ref_view_cnt(0.5)는 상관관계가 깊다.
df_Average_minimum_temperature = df[["Average minimum temperature (°C)","leis_sports_cnt","ref_view_cnt"]]
df_Average_minimum_temperature.corr()
# Out:
#                                   Average minimum temperature (°C)  \
# Average minimum temperature (°C)                          1.000000
# leis_sports_cnt                                          -0.177321
# ref_view_cnt                                              0.554835
#
#                                   leis_sports_cnt  ref_view_cnt
# Average minimum temperature (°C)        -0.177321      0.554835
# leis_sports_cnt                          1.000000      0.087771
# ref_view_cnt                             0.087771      1.000000

# %% [markdown]
# ### Maximum temperature (°C)분석

# %%
# 상관관계 분석을 해 보니 Maximum temperature (°C)와 leis_sports_cnt(-0.1)는 상관관계가 없고,
# ref_view_cnt(0.5)는 상관관계가 깊다.
df_Maximum_traturempee = df[["Maximum temperature (°C)","leis_sports_cnt","ref_view_cnt"]]
df_Maximum_traturempee.corr()
# Out:
#                           Maximum temperature (°C)  leis_sports_cnt  \
# Maximum temperature (°C)                  1.000000        -0.165561
# leis_sports_cnt                          -0.165561         1.000000
# ref_view_cnt                              0.500803         0.087771
#
#                           ref_view_cnt
# Maximum temperature (°C)      0.500803
# leis_sports_cnt               0.087771
# ref_view_cnt                  1.000000

# %% [markdown]
# ### Minimum temperature (°C)분석

# %%
# 상관관계 분석을 해 보니 Minimum temperature (°C)와 leis_sports_cnt(-0.2)는 상관관계가 없고,
# ref_view_cnt(0.5)는 상관관계가 깊다.
df_Minimum_traturempee = df[["Minimum temperature (°C)","leis_sports_cnt","ref_view_cnt"]]
df_Minimum_traturempee.corr()
# Out:
#                           Minimum temperature (°C)  leis_sports_cnt  \
# Minimum temperature (°C)                  1.000000        -0.207130
# leis_sports_cnt                          -0.207130         1.000000
# ref_view_cnt                              0.582554         0.087771
#
#                           ref_view_cnt
# Minimum temperature (°C)      0.582554
# leis_sports_cnt               0.087771
# ref_view_cnt                  1.000000

# %% [markdown]
# ### Average wind speed (m/s)분석

# %%
# 상관관계 분석을 해 보니 Average wind speed (m/s)와 leis_sports_cnt(0.04)는 상관관계가 없고,
# ref_view_cnt(-0.3)는 상관관계가 있다.
df_Average_wind_speed = df[["Average wind speed (m/s)","leis_sports_cnt","ref_view_cnt"]]
df_Average_wind_speed.corr()
# Out:
#                           Average wind speed (m/s)  leis_sports_cnt  \
# Average wind speed (m/s)                  1.000000         0.048449
# leis_sports_cnt                           0.048449         1.000000
# ref_view_cnt                             -0.367868         0.087771
#
#                           ref_view_cnt
# Average wind speed (m/s)     -0.367868
# leis_sports_cnt               0.087771
# ref_view_cnt                  1.000000

# %% [markdown]
# ### season분석

# %%
# season을 분석하기 위해서 원핫인코딩을 실행한다.
df = pd.get_dummies(df, columns = ['season'])
df
# Out:
#     base_month  Vacation  holiday  weekend  Average temperature (°C)  \
# 0     201501.0       1.0      1.0      9.0                       7.4
# 1     201502.0       0.0      3.0      4.0                       7.3
# 2     201503.0       0.0      1.0      8.0                      10.4
# 3     201504.0       0.0      0.0      6.0                      15.1
# 4     201505.0       0.0      2.0     10.0                      18.8
# ..         ...       ...      ...      ...                       ...
# 86    202203.0       0.0      2.0      8.0                      11.4
# 87    202204.0       0.0      1.0      9.0                      15.5
# 88    202205.0       0.0      2.0      9.0                      19.4
# 89    202206.0       1.0      0.0      8.0                      23.9
# 90    202207.0       1.0      1.0     10.0                      28.4
#
#     Average maximum temperature (°C)  Average minimum temperature (°C)  \
# 0                               10.2                               4.9
# 1                               10.1                               4.7
# 2                               13.6                               7.3
# 3                               19.2                              12.0
# 4                               22.7                              15.9
# ..                               ...                               ...
# 86                              15.5                               7.8
# 87                              19.6                              11.9
# 88                              23.1                              15.8
# 89                              27.5                              21.1
# 90                              31.8                              25.7
#
#     Maximum temperature (°C)  Minimum temperature (°C)  \
# 0                       17.5                       1.2
# 1                       17.3                      -0.7
# 2                       22.2                       0.2
# 3                       27.7                       7.0
# 4                       29.4                      11.0
# ..                       ...                       ...
# 86                      22.3                       4.5
# 87                      26.7                       5.6
# 88                      29.0                       9.5
# 89                      34.4                      17.3
# 90                      36.0                      23.2
#
#     The day the highest temperature appeared (yyyymmdd)  ...  1.0m평균지중온도(°C)  \
# 0                                          20150105.0    ...             9.6
# 1                                          20150221.0    ...             8.0
# 2                                          20150331.0    ...             9.6
# 3                                          20150402.0    ...            13.7
# 4                                          20150514.0    ...            18.1
# ..                                                ...    ...             ...
# 86                                         20220312.0    ...            10.7
# 87                                         20220425.0    ...            14.8
# 88                                         20220527.0    ...            18.8
# 89                                         20220626.0    ...            22.5
# 90                                         20220728.0    ...            27.2
#
#     1.5m평균지중온도(°C)  3.0m평균지중온도(°C)  5.0m평균지중온도(°C)  leis_sports_cnt  \
# 0              9.6            15.6            18.4         127063.0
# 1              7.7            12.2            16.9         134718.0
# 2              8.9            11.1            15.8         143528.0
# 3             12.6            12.1            14.9         146259.0
# 4             16.3            14.7            14.8         179944.0
# ..             ...             ...             ...              ...
# 86            10.7            13.5            17.2          74732.0
# 87            13.9            13.9            16.5         102377.0
# 88            17.2            15.6            16.1          94892.0
# 89            20.4            17.9            16.5         106281.0
# 90            24.8            22.0            17.7          93984.0
#
#     ref_view_cnt  season_autumn  season_spring  season_summer  season_winter
# 0       521304.0              0              0              0              1
# 1       459032.0              0              0              0              1
# 2       490004.0              0              1              0              0
# 3       623087.0              0              1              0              0
# 4       628479.0              0              1              0              0
# ..           ...            ...            ...            ...            ...
# 86      617995.0              0              1              0              0
# 87      843283.0              0              1              0              0
# 88      918511.0              0              1              0              0
# 89      970029.0              0              0              1              0
# 90      940925.0              0              0              1              0
#
# [91 rows x 63 columns]

# %%
# 상관관계 분석을 해보니 leis_sports_cnt(spring = 0.06, summer = -0.1, autumn = 0.1, wintter = -0.02)하고는 관계가 있는 것이 없고,
# ref_view_cnt하고는 summer이 가장 관계가 깊고(0.5), winter가 그 다음으로 반비례하여 높다.(-0.3) 나머지는 상관관계가 없다.(spring = -0.1, autumn = -0.08)
df_season = df[["season_autumn","season_spring","season_summer","season_winter","leis_sports_cnt","ref_view_cnt"]]
df_season.corr()
# Out:
#                  season_autumn  season_spring  season_summer  season_winter  \
# season_autumn         1.000000      -0.327815      -0.318544      -0.318544
# season_spring        -0.327815       1.000000      -0.348079      -0.348079
# season_summer        -0.318544      -0.348079       1.000000      -0.338235
# season_winter        -0.318544      -0.348079      -0.338235       1.000000
# leis_sports_cnt       0.159662       0.064811      -0.194176      -0.026330
# ref_view_cnt         -0.082484      -0.134630       0.518904      -0.302427
#
#                  leis_sports_cnt  ref_view_cnt
# season_autumn           0.159662     -0.082484
# season_spring           0.064811     -0.134630
# season_summer          -0.194176      0.518904
# season_winter          -0.026330     -0.302427
# leis_sports_cnt         1.000000      0.087771
# ref_view_cnt            0.087771      1.000000

# %% [markdown]
# ### 데이터프레임 전체 상관관계 분석

# %%
df_Average_wind_speed = df
df_Average_wind_speed.corr()
# Out:
#                           base_month  Vacation   holiday   weekend  \
# base_month                  1.000000  0.023100  0.025016  0.149322
# Vacation                    0.023100  1.000000 -0.185762  0.147970
# holiday                     0.025016 -0.185762  1.000000 -0.044243
# weekend                     0.149322  0.147970 -0.044243  1.000000
# Average temperature (°C)    0.000328  0.396794 -0.095213  0.163353
# ...                              ...       ...       ...       ...
# ref_view_cnt                0.146686  0.391629 -0.083187  0.202462
# season_autumn              -0.067584 -0.393700  0.181737  0.026480
# season_spring               0.046156 -0.430203 -0.051248 -0.018084
# season_summer               0.012356  0.809104 -0.302245  0.073348
# season_winter               0.006364  0.008795  0.178018 -0.080683
#
#                           Average temperature (°C)  \
# base_month                                0.000328
# Vacation                                  0.396794
# holiday                                  -0.095213
# weekend                                   0.163353
# Average temperature (°C)                  1.000000
# ...                                            ...
# ref_view_cnt                              0.552147
# season_autumn                             0.168687
# season_spring                            -0.136271
# season_summer                             0.714419
# season_winter                            -0.739784
#
#                           Average maximum temperature (°C)  \
# base_month                                        0.016248
# Vacation                                          0.373742
# holiday                                          -0.109355
# weekend                                           0.165784
# Average temperature (°C)                          0.997560
# ...                                                    ...
# ref_view_cnt                                      0.551348
# season_autumn                                     0.151736
# season_spring                                    -0.087078
# season_summer                                     0.704905
# season_winter                                    -0.763716
#
#                           Average minimum temperature (°C)  \
# base_month                                       -0.011081
# Vacation                                          0.420457
# holiday                                          -0.086330
# weekend                                           0.164281
# Average temperature (°C)                          0.998425
# ...                                                    ...
# ref_view_cnt                                      0.554835
# season_autumn                                     0.175711
# season_spring                                    -0.175829
# season_summer                                     0.724044
# season_winter                                    -0.716108
#
#                           Maximum temperature (°C)  Minimum temperature (°C)  \
# base_month                                0.006681                  0.003920
# Vacation                                  0.327304                  0.438528
# holiday                                  -0.093950                 -0.085188
# weekend                                   0.182217                  0.140468
# Average temperature (°C)                  0.957180                  0.981291
# ...                                            ...                       ...
# ref_view_cnt                              0.500803                  0.582554
# season_autumn                             0.109319                  0.151312
# season_spring                            -0.032781                 -0.179921
# season_summer                             0.664608                  0.732497
# season_winter                            -0.737352                 -0.696756
#
#                           The day the highest temperature appeared (yyyymmdd)  \
# base_month                                                         1.000000
# Vacation                                                           0.023186
# holiday                                                            0.024915
# weekend                                                            0.149336
# Average temperature (°C)                                           0.000305
# ...                                                                     ...
# ref_view_cnt                                                       0.146713
# season_autumn                                                     -0.067798
# season_spring                                                      0.046240
# season_summer                                                      0.012460
# season_winter                                                      0.006383
#
#                           ...  1.0m평균지중온도(°C)  1.5m평균지중온도(°C)  3.0m평균지중온도(°C)  \
# base_month                ...        0.026306        0.036386        0.051171
# Vacation                  ...        0.361367        0.311813        0.266405
# holiday                   ...       -0.057117       -0.030686        0.030656
# weekend                   ...        0.198655        0.200422        0.205316
# Average temperature (°C)  ...        0.951479        0.905394        0.651429
# ...                       ...             ...             ...             ...
# ref_view_cnt              ...        0.531603        0.495269        0.369444
# season_autumn             ...        0.354988        0.451064        0.588383
# season_spring             ...       -0.330565       -0.394063       -0.655009
# season_summer             ...        0.639045        0.571177        0.391630
# season_winter             ...       -0.648017       -0.608908       -0.297899
#
#                           5.0m평균지중온도(°C)  leis_sports_cnt  ref_view_cnt  \
# base_month                      0.124491        -0.292757      0.146686
# Vacation                       -0.126867        -0.140896      0.391629
# holiday                         0.161303         0.003873     -0.083187
# weekend                         0.112462         0.015566      0.202462
# Average temperature (°C)        0.001501        -0.178488      0.552147
# ...                                  ...              ...           ...
# ref_view_cnt                   -0.026825         0.087771      1.000000
# season_autumn                   0.723226         0.159662     -0.082484
# season_spring                  -0.647116         0.064811     -0.134630
# season_summer                  -0.200511        -0.194176      0.518904
# season_winter                   0.155512        -0.026330     -0.302427
#
#                           season_autumn  season_spring  season_summer  \
# base_month                    -0.067584       0.046156       0.012356
# Vacation                      -0.393700      -0.430203       0.809104
# holiday                        0.181737      -0.051248      -0.302245
# weekend                        0.026480      -0.018084       0.073348
# Average temperature (°C)       0.168687      -0.136271       0.714419
# ...                                 ...            ...            ...
# ref_view_cnt                  -0.082484      -0.134630       0.518904
# season_autumn                  1.000000      -0.327815      -0.318544
# season_spring                 -0.327815       1.000000      -0.348079
# season_summer                 -0.318544      -0.348079       1.000000
# season_winter                 -0.318544      -0.348079      -0.338235
#
#                           season_winter
# base_month                     0.006364
# Vacation                       0.008795
# holiday                        0.178018
# weekend                       -0.080683
# Average temperature (°C)      -0.739784
# ...                                 ...
# ref_view_cnt                  -0.302427
# season_autumn                 -0.318544
# season_spring                 -0.348079
# season_summer                 -0.338235
# season_winter                  1.000000
#
# [63 rows x 63 columns]

# %%
# ref_view_cnt를 예측하기 위해서 필요한 25가지 컬럼을 뽑아보았다.
corr_df = df.corr()

corr5 = corr_df.nlargest(26, 'ref_view_cnt')
corr5 = corr5[list(corr5.index)]
corr5['ref_view_cnt']
# Out:
# ref_view_cnt                        1.000000
# Minimum temperature (°C)            0.582554
# 평균지면온도(°C)                          0.559266
# Average minimum temperature (°C)    0.554835
# 0.3m평균지중온도(°C)                      0.554146
# 최저초상온도(°C)                          0.553892
# Average temperature (°C)            0.552147
# 소형총증발량(mm)                          0.551732
# Average maximum temperature (°C)    0.551348
# 평균수증기압(hPa)                         0.550602
# 0.05m평균지중온도(°C)                     0.550031
# 0.2m평균지중온도(°C)                      0.549281
# 0.5m평균지중온도(°C)                      0.548963
# 평균 최저초상온도(°C)                       0.547768
# 0.1m평균지중온도(°C)                      0.544608
# 평균이슬점온도(°C)                         0.539215
# 1.0m평균지중온도(°C)                      0.531603
# season_summer                       0.518904
# 최고수증기압(hPa)                         0.515171
# Maximum temperature (°C)            0.500803
# 1.5m평균지중온도(°C)                      0.495269
# 최저수증기압(hPa)                         0.475060
# 소형일최대증발량(mm)                        0.452907
# 합계 일사량(MJ/m2)                       0.424559
# Vacation                            0.391629
# 3.0m평균지중온도(°C)                      0.369444
# Name: ref_view_cnt, dtype: float64

# %%
corr_df = df.corr()

corr5 = corr_df.nlargest(26, 'leis_sports_cnt')
corr5 = corr5[list(corr5.index)]
corr5['leis_sports_cnt']
# Out:
# leis_sports_cnt              1.000000
# 평균현지기압(hPa)                  0.226816
# 평균해면기압(hPa)                  0.225545
# 최고해면기압(hPa)                  0.213945
# 최저해면기압(hPa)                  0.212689
# 최다풍향(16방위)                   0.191526
# season_autumn                0.159662
# ref_view_cnt                 0.087771
# 최대순간풍속 풍향(16방위)              0.081648
# season_spring                0.064811
# Average wind speed (m/s)     0.048449
# 최대풍속 풍향(16방위)                0.033766
# weekend                      0.015566
# holiday                      0.003873
# 일조율(%)                      -0.003976
# 5.0m평균지중온도(°C)              -0.010070
# season_winter               -0.026330
# Maximum wind speed (m/s)    -0.028504
# 합계 일조시간(hr)                 -0.054630
# 최대순간풍속(m/s)                 -0.055994
# 3.0m평균지중온도(°C)              -0.098922
# 1.5m평균지중온도(°C)              -0.125807
# Average Cloudiness (1/10)   -0.127933
# 합계 일사량(MJ/m2)               -0.133083
# 1.0m평균지중온도(°C)              -0.137964
# 평균 최저초상온도(°C)               -0.140237
# Name: leis_sports_cnt, dtype: float64

# %% [markdown]
# # ref_view_cnt 예측모델

# %%
# 실제 7월 데이터를 이용하여 모델의 성능을 시험할 예정

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
        # m_s_e, r2(선형회귀모델 적합도 : 분산값, 1에 가까울수록 적합도 높음)

# feature, target 데이터 분리
X_data = df.drop(['leis_sports_cnt', 'ref_view_cnt'], axis = 1)
y_target = df['ref_view_cnt']
# train, test 데이터 분리
X_train , X_test , y_train , y_test = train_test_split(X_data , y_target , test_size=0.3, random_state=156)

# Linear Regression
lr = LinearRegression()

# fit 메소드 학습 : 주어진 데이터로 estimator(사이킷런이 제공) 알고리즘 학습
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(X_train.shape, X_test.shape)
# Out:
# (63, 61) (28, 61)

# %%
# predict 메소드 : 학습된 모델로 예측을 수행
y_preds = lr.predict(X_test)
y_preds[0:5]
# Out:
# array([ 320103.7988306 , -149755.16144833,  664995.0372463 ,
#         492736.75834464,  574057.19148856])

# %%
# rmse를 활용한 평가
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)

print(f'MSE : {mse:.3f}, RMSE: {rmse:.3f}')
print(f'Variance score : {r2_score(y_test, y_preds):.3f}')
# Out:
# MSE : 161332290750.352, RMSE: 401661.911
# Variance score : -6.223
